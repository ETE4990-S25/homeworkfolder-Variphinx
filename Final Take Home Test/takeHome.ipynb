# %% [markdown]
# ``` py
#
# !pip install takeHomeTest
# import takeHomeTest
#
# !pip install time
# from time import oneWeek as panic
#
# panic.dump(takeHomeTest)
#
#
# print("Welcome to your take home final!\n")
# ```
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ------------------------------------------- The Legend of Python --------------------------------------------
# **Lore**
#
# In the Kingdom of Pyrovia, all nations once traded in harmony. But since the Shattering of the Global APIs, the knowledge of currency exchange — locked away in XML scrolls — has scattered across the timelines. These scrolls reside in a mysterious repository known only as floatrates.com.
#
# The High Council of Programmers has summoned you (and only you), young code-wielder, to begin your final trial. It is divided into 2 parts.
# * Quest 1 (50xp): Retrieving the scrolls of time - Threading and Json save and parsing
# * Quest 2 (50xp): Decipher the scrolls - Perform EDA on the data.
#
# ------ ------ ------ ------ Extra credit ------ ------ ------ ------
# * Side Quest 1 (10xp*): Lay down seeds for those that follow - create error logs
# * Side Quest 2 (10xp*): The Quest of reflection  - Use profiling on your code to fully understand it
#
# *any points over 100% will be rolled over into your final grade.
#
# I may not have time to run all of your code so make sure you very clearly take notes and communicate successes, issues, and lessons learned.
# Please stay off Chat GPT and stack overflow (and like). You should have most everything you need in the notes.

# %% [markdown]
# --------------------------------------------
# # Quest 1 (50 xp): Retrieving the Scrolls of Time
# Retrieve historical exchange rate data from floatrates.com for one of the (Ideally randomly pick) 52 available currencies, starting from the first record on May 4, 2011, until the present day.
#
# - You may store the data as-is in XML, or convert it to JSON, you may use the supplied code below as a starter.
#
# - Organize each currency into its own directory.
#
# - Ensure your code is modular, maintainable, and robust against timeouts or malformed entries.
#
# ## Notes from the Grand Master
# * Threading is your ally. But do not burn out your ally as they have limited resources. You may use the threading or multi-core to parallelize downloads — but mind the server’s load. Around 10 threads is wise.
#     - You should have around 5040 queries.
#
# * XML Scrolls is a new and unfamiliar beast. Therefore takeing on this beast will wield 5 extra experience points. You will not be penalized for choosing to use JSON
#
# *  Use the Save. Nothing is worse than losing experience you have already gained. Save the raw XML (or converted JSON) using timestamped (in my example below) files so you do not need to look it up again. Ie. If you put in a start date and your program has already read that data it should not pull that date again. (it would be a good idea to delete your data and run it top to bottom before final submission)
#
# * Design gracefully. Structure your project with clear modules: downloader.py, parser.py, and so on.
#
# * Log your quest progress in your quest book to show the Grand Master what you learned this is very important.

# %% [markdown]
# --------------------------------------------

# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.14.2
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\David\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
rates = ["EUR", "GBP", "USD", "DZD", "AUD", "BWP", "BND", "CAD", "CLP", "CNY", "COP", "CZK", "DKK", "HUF", "ISK", "INR", "IDR", "ILS", "KZT", "KRW", "KWD", "LYD", "MYR", "MUR", "NPR", "NZD", "NOK", "OMR", "PKR", "PLN", "QAR", "RUB", "SAR", "SGD", "ZAR", "LKR", "SEK", "CHF", "THB", "TTD"]
ratesForBase = [r for r in rates if r != "USD" and r != "EUR" and r != "GBP"]

# %%
import requests
import xmltodict
import json
import random

# URL of the XML data
date = "2011-05-04"
base = random.choice(ratesForBase)
url = f"https://www.floatrates.com/historical-exchange-rates.html?operation=rates&pb_id=1775&page=historical&currency_date={date}&base_currency_code={base}&format_type=xml"
print(url)
# Fetch the XML data
response = requests.get(url)
response.raise_for_status()  # Ensure we notice bad responses

# Parse the XML data to a Python dictionary
data_dict = xmltodict.parse(response.text)

# Convert the dictionary to a JSON string
json_data = json.dumps(data_dict, indent=4)

# Print the JSON data
print(json_data)

# Optionally, write the JSON data to a file
with open(f"{date}_exchange_rates_{base}.json", "w") as json_file:
    json_file.write(json_data)
# Out:
# https://www.floatrates.com/historical-exchange-rates.html?operation=rates&pb_id=1775&page=historical&currency_date=2011-05-04&base_currency_code=SEK&format_type=xml
# {
#     "channel": {
#         "title": "XML Historical Foreign Exchange Rates for Swedish Krona (SEK) (4 May 2011)",
#         "link": "http://www.floatrates.com/currency/sek/",
#         "xmlLink": "http://www.floatrates.com/daily/sek.xml",
#         "description": "XML historical foreign exchange rates for Swedish Krona (SEK) from the Float Rates. Published at 4 May 2011.",
#         "language": "en",
#         "baseCurrency": "SEK",
#         "pubDate": "Wed, 4 May 2011",
#         "lastBuildDate": "Wed, 4 May 2011",
#         "item": [
#             {
#                 "title": "1 SEK = 0.111191 EUR",
#                 "link": "http://www.floatrates.com/sek/eur/",
#                 "description": "1 Swedish Krona = 0.111191 Euro",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "EUR",
#                 "targetName": "Euro",
#                 "exchangeRate": "0.111191",
#                 "inverseRate": "8.993505",
#                 "inverseDescription": "1 Euro = 8.993505 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.100164 GBP",
#                 "link": "http://www.floatrates.com/sek/gbp/",
#                 "description": "1 Swedish Krona = 0.100164 U.K. Pound Sterling",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "GBP",
#                 "targetName": "U.K. Pound Sterling",
#                 "exchangeRate": "0.100164",
#                 "inverseRate": "9.983658",
#                 "inverseDescription": "1 U.K. Pound Sterling = 9.983658 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.165475 USD",
#                 "link": "http://www.floatrates.com/sek/usd/",
#                 "description": "1 Swedish Krona = 0.165475 U.S. Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "USD",
#                 "targetName": "U.S. Dollar",
#                 "exchangeRate": "0.165475",
#                 "inverseRate": "6.043210",
#                 "inverseDescription": "1 U.S. Dollar = 6.043210 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 11.797207 DZD",
#                 "link": "http://www.floatrates.com/sek/dzd/",
#                 "description": "1 Swedish Krona = 11.797207 Algerian Dinar",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "DZD",
#                 "targetName": "Algerian Dinar",
#                 "exchangeRate": "11.797207",
#                 "inverseRate": "0.084766",
#                 "inverseDescription": "1 Algerian Dinar = 0.084766 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.152749 AUD",
#                 "link": "http://www.floatrates.com/sek/aud/",
#                 "description": "1 Swedish Krona = 0.152749 Australian Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "AUD",
#                 "targetName": "Australian Dollar",
#                 "exchangeRate": "0.152749",
#                 "inverseRate": "6.546689",
#                 "inverseDescription": "1 Australian Dollar = 6.546689 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 1.054652 BWP",
#                 "link": "http://www.floatrates.com/sek/bwp/",
#                 "description": "1 Swedish Krona = 1.054652 Botswana Pula",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "BWP",
#                 "targetName": "Botswana Pula",
#                 "exchangeRate": "1.054652",
#                 "inverseRate": "0.948180",
#                 "inverseDescription": "1 Botswana Pula = 0.948180 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.203567 BND",
#                 "link": "http://www.floatrates.com/sek/bnd/",
#                 "description": "1 Swedish Krona = 0.203567 Brunei Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "BND",
#                 "targetName": "Brunei Dollar",
#                 "exchangeRate": "0.203567",
#                 "inverseRate": "4.912380",
#                 "inverseDescription": "1 Brunei Dollar = 4.912380 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.158221 CAD",
#                 "link": "http://www.floatrates.com/sek/cad/",
#                 "description": "1 Swedish Krona = 0.158221 Canadian Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "CAD",
#                 "targetName": "Canadian Dollar",
#                 "exchangeRate": "0.158221",
#                 "inverseRate": "6.320263",
#                 "inverseDescription": "1 Canadian Dollar = 6.320263 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 76.626496 CLP",
#                 "link": "http://www.floatrates.com/sek/clp/",
#                 "description": "1 Swedish Krona = 76.626496 Chilean Peso",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "CLP",
#                 "targetName": "Chilean Peso",
#                 "exchangeRate": "76.626496",
#                 "inverseRate": "0.013050",
#                 "inverseDescription": "1 Chilean Peso = 0.013050 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 1.075371 CNY",
#                 "link": "http://www.floatrates.com/sek/cny/",
#                 "description": "1 Swedish Krona = 1.075371 Chinese Yuan",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "CNY",
#                 "targetName": "Chinese Yuan",
#                 "exchangeRate": "1.075371",
#                 "inverseRate": "0.929911",
#                 "inverseDescription": "1 Chinese Yuan = 0.929911 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 292.402552 COP",
#                 "link": "http://www.floatrates.com/sek/cop/",
#                 "description": "1 Swedish Krona = 292.402552 Colombian Peso",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "COP",
#                 "targetName": "Colombian Peso",
#                 "exchangeRate": "292.402552",
#                 "inverseRate": "0.003420",
#                 "inverseDescription": "1 Colombian Peso = 0.003420 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 2.691577 CZK",
#                 "link": "http://www.floatrates.com/sek/czk/",
#                 "description": "1 Swedish Krona = 2.691577 Czech Koruna",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "CZK",
#                 "targetName": "Czech Koruna",
#                 "exchangeRate": "2.691577",
#                 "inverseRate": "0.371529",
#                 "inverseDescription": "1 Czech Koruna = 0.371529 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.829130 DKK",
#                 "link": "http://www.floatrates.com/sek/dkk/",
#                 "description": "1 Swedish Krona = 0.829130 Danish Krone",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "DKK",
#                 "targetName": "Danish Krone",
#                 "exchangeRate": "0.829130",
#                 "inverseRate": "1.206084",
#                 "inverseDescription": "1 Danish Krone = 1.206084 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 29.509287 HUF",
#                 "link": "http://www.floatrates.com/sek/huf/",
#                 "description": "1 Swedish Krona = 29.509287 Hungarian Forint",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "HUF",
#                 "targetName": "Hungarian Forint",
#                 "exchangeRate": "29.509287",
#                 "inverseRate": "0.033888",
#                 "inverseDescription": "1 Hungarian Forint = 0.033888 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 18.432257 ISK",
#                 "link": "http://www.floatrates.com/sek/isk/",
#                 "description": "1 Swedish Krona = 18.432257 Icelandic Krona",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "ISK",
#                 "targetName": "Icelandic Krona",
#                 "exchangeRate": "18.432257",
#                 "inverseRate": "0.054253",
#                 "inverseDescription": "1 Icelandic Krona = 0.054253 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 7.371901 INR",
#                 "link": "http://www.floatrates.com/sek/inr/",
#                 "description": "1 Swedish Krona = 7.371901 Indian Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "INR",
#                 "targetName": "Indian Rupee",
#                 "exchangeRate": "7.371901",
#                 "inverseRate": "0.135650",
#                 "inverseDescription": "1 Indian Rupee = 0.135650 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 1,415.913210 IDR",
#                 "link": "http://www.floatrates.com/sek/idr/",
#                 "description": "1 Swedish Krona = 1,415.913210 Indonesian Rupiah",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "IDR",
#                 "targetName": "Indonesian Rupiah",
#                 "exchangeRate": "1,415.913210",
#                 "inverseRate": "0.000706",
#                 "inverseDescription": "1 Indonesian Rupiah = 0.000706 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.561422 ILS",
#                 "link": "http://www.floatrates.com/sek/ils/",
#                 "description": "1 Swedish Krona = 0.561422 Israeli New Sheqel",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "ILS",
#                 "targetName": "Israeli New Sheqel",
#                 "exchangeRate": "0.561422",
#                 "inverseRate": "1.781192",
#                 "inverseDescription": "1 Israeli New Sheqel = 1.781192 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 24.124596 KZT",
#                 "link": "http://www.floatrates.com/sek/kzt/",
#                 "description": "1 Swedish Krona = 24.124596 Kazakhstani Tenge",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "KZT",
#                 "targetName": "Kazakhstani Tenge",
#                 "exchangeRate": "24.124596",
#                 "inverseRate": "0.041451",
#                 "inverseDescription": "1 Kazakhstani Tenge = 0.041451 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 177.232469 KRW",
#                 "link": "http://www.floatrates.com/sek/krw/",
#                 "description": "1 Swedish Krona = 177.232469 South Korean Won",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "KRW",
#                 "targetName": "South Korean Won",
#                 "exchangeRate": "177.232469",
#                 "inverseRate": "0.005642",
#                 "inverseDescription": "1 South Korean Won = 0.005642 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.045406 KWD",
#                 "link": "http://www.floatrates.com/sek/kwd/",
#                 "description": "1 Swedish Krona = 0.045406 Kuwaiti Dinar",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "KWD",
#                 "targetName": "Kuwaiti Dinar",
#                 "exchangeRate": "0.045406",
#                 "inverseRate": "22.023360",
#                 "inverseDescription": "1 Kuwaiti Dinar = 22.023360 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.319764 LYD",
#                 "link": "http://www.floatrates.com/sek/lyd/",
#                 "description": "1 Swedish Krona = 0.319764 Libyan Dinar",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "LYD",
#                 "targetName": "Libyan Dinar",
#                 "exchangeRate": "0.319764",
#                 "inverseRate": "3.127308",
#                 "inverseDescription": "1 Libyan Dinar = 3.127308 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.492951 MYR",
#                 "link": "http://www.floatrates.com/sek/myr/",
#                 "description": "1 Swedish Krona = 0.492951 Malaysian Ringgit",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "MYR",
#                 "targetName": "Malaysian Ringgit",
#                 "exchangeRate": "0.492951",
#                 "inverseRate": "2.028599",
#                 "inverseDescription": "1 Malaysian Ringgit = 2.028599 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 4.505635 MUR",
#                 "link": "http://www.floatrates.com/sek/mur/",
#                 "description": "1 Swedish Krona = 4.505635 Mauritian Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "MUR",
#                 "targetName": "Mauritian Rupee",
#                 "exchangeRate": "4.505635",
#                 "inverseRate": "0.221944",
#                 "inverseDescription": "1 Mauritian Rupee = 0.221944 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 11.771890 NPR",
#                 "link": "http://www.floatrates.com/sek/npr/",
#                 "description": "1 Swedish Krona = 11.771890 Nepalese Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "NPR",
#                 "targetName": "Nepalese Rupee",
#                 "exchangeRate": "11.771890",
#                 "inverseRate": "0.084948",
#                 "inverseDescription": "1 Nepalese Rupee = 0.084948 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.207691 NZD",
#                 "link": "http://www.floatrates.com/sek/nzd/",
#                 "description": "1 Swedish Krona = 0.207691 New Zealand Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "NZD",
#                 "targetName": "New Zealand Dollar",
#                 "exchangeRate": "0.207691",
#                 "inverseRate": "4.814834",
#                 "inverseDescription": "1 New Zealand Dollar = 4.814834 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.875183 NOK",
#                 "link": "http://www.floatrates.com/sek/nok/",
#                 "description": "1 Swedish Krona = 0.875183 Norwegian Krone",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "NOK",
#                 "targetName": "Norwegian Krone",
#                 "exchangeRate": "0.875183",
#                 "inverseRate": "1.142618",
#                 "inverseDescription": "1 Norwegian Krone = 1.142618 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.063625 OMR",
#                 "link": "http://www.floatrates.com/sek/omr/",
#                 "description": "1 Swedish Krona = 0.063625 Omani Rial",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "OMR",
#                 "targetName": "Omani Rial",
#                 "exchangeRate": "0.063625",
#                 "inverseRate": "15.717061",
#                 "inverseDescription": "1 Omani Rial = 15.717061 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 13.950947 PKR",
#                 "link": "http://www.floatrates.com/sek/pkr/",
#                 "description": "1 Swedish Krona = 13.950947 Pakistani Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "PKR",
#                 "targetName": "Pakistani Rupee",
#                 "exchangeRate": "13.950947",
#                 "inverseRate": "0.071680",
#                 "inverseDescription": "1 Pakistani Rupee = 0.071680 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.438233 PLN",
#                 "link": "http://www.floatrates.com/sek/pln/",
#                 "description": "1 Swedish Krona = 0.438233 Polish Zloty",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "PLN",
#                 "targetName": "Polish Zloty",
#                 "exchangeRate": "0.438233",
#                 "inverseRate": "2.281889",
#                 "inverseDescription": "1 Polish Zloty = 2.281889 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.602329 QAR",
#                 "link": "http://www.floatrates.com/sek/qar/",
#                 "description": "1 Swedish Krona = 0.602329 Qatari Rial",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "QAR",
#                 "targetName": "Qatari Rial",
#                 "exchangeRate": "0.602329",
#                 "inverseRate": "1.660223",
#                 "inverseDescription": "1 Qatari Rial = 1.660223 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 4.521286 RUB",
#                 "link": "http://www.floatrates.com/sek/rub/",
#                 "description": "1 Swedish Krona = 4.521286 Russian Rouble",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "RUB",
#                 "targetName": "Russian Rouble",
#                 "exchangeRate": "4.521286",
#                 "inverseRate": "0.221176",
#                 "inverseDescription": "1 Russian Rouble = 0.221176 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.620531 SAR",
#                 "link": "http://www.floatrates.com/sek/sar/",
#                 "description": "1 Swedish Krona = 0.620531 Saudi Riyal",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "SAR",
#                 "targetName": "Saudi Riyal",
#                 "exchangeRate": "0.620531",
#                 "inverseRate": "1.611523",
#                 "inverseDescription": "1 Saudi Riyal = 1.611523 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.203409 SGD",
#                 "link": "http://www.floatrates.com/sek/sgd/",
#                 "description": "1 Swedish Krona = 0.203409 Singapore Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "SGD",
#                 "targetName": "Singapore Dollar",
#                 "exchangeRate": "0.203409",
#                 "inverseRate": "4.916214",
#                 "inverseDescription": "1 Singapore Dollar = 4.916214 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 1.096092 ZAR",
#                 "link": "http://www.floatrates.com/sek/zar/",
#                 "description": "1 Swedish Krona = 1.096092 South African Rand",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "ZAR",
#                 "targetName": "South African Rand",
#                 "exchangeRate": "1.096092",
#                 "inverseRate": "0.912333",
#                 "inverseDescription": "1 South African Rand = 0.912333 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 18.166091 LKR",
#                 "link": "http://www.floatrates.com/sek/lkr/",
#                 "description": "1 Swedish Krona = 18.166091 Sri Lanka Rupee",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "LKR",
#                 "targetName": "Sri Lanka Rupee",
#                 "exchangeRate": "18.166091",
#                 "inverseRate": "0.055048",
#                 "inverseDescription": "1 Sri Lanka Rupee = 0.055048 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 1.000000 SEK",
#                 "link": "http://www.floatrates.com/sek/sek/",
#                 "description": "1 Swedish Krona = 1.000000 Swedish Krona",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "SEK",
#                 "targetName": "Swedish Krona",
#                 "exchangeRate": "1.000000",
#                 "inverseRate": "1.000000",
#                 "inverseDescription": "1 Swedish Krona = 1.000000 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.142675 CHF",
#                 "link": "http://www.floatrates.com/sek/chf/",
#                 "description": "1 Swedish Krona = 0.142675 Swiss Franc",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "CHF",
#                 "targetName": "Swiss Franc",
#                 "exchangeRate": "0.142675",
#                 "inverseRate": "7.008932",
#                 "inverseDescription": "1 Swiss Franc = 7.008932 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 4.968207 THB",
#                 "link": "http://www.floatrates.com/sek/thb/",
#                 "description": "1 Swedish Krona = 4.968207 Thai Baht",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "THB",
#                 "targetName": "Thai Baht",
#                 "exchangeRate": "4.968207",
#                 "inverseRate": "0.201280",
#                 "inverseDescription": "1 Thai Baht = 0.201280 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 1.058229 TTD",
#                 "link": "http://www.floatrates.com/sek/ttd/",
#                 "description": "1 Swedish Krona = 1.058229 Trinidad Tobago Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "TTD",
#                 "targetName": "Trinidad Tobago Dollar",
#                 "exchangeRate": "1.058229",
#                 "inverseRate": "0.944975",
#                 "inverseDescription": "1 Trinidad Tobago Dollar = 0.944975 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.607707 AED",
#                 "link": "http://www.floatrates.com/sek/aed/",
#                 "description": "1 Swedish Krona = 0.607707 U.A.E Dirham",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "AED",
#                 "targetName": "U.A.E Dirham",
#                 "exchangeRate": "0.607707",
#                 "inverseRate": "1.645530",
#                 "inverseDescription": "1 U.A.E Dirham = 1.645530 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.709772 VEF",
#                 "link": "http://www.floatrates.com/sek/vef/",
#                 "description": "1 Swedish Krona = 0.709772 Venezuelan Bolivar (till 20 August 2018)",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "VEF",
#                 "targetName": "Venezuelan Bolivar (till 20 August 2018)",
#                 "exchangeRate": "0.709772",
#                 "inverseRate": "1.408904",
#                 "inverseDescription": "1 Venezuelan Bolivar (till 20 August 2018) = 1.408904 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 13.411901 JPY",
#                 "link": "http://www.floatrates.com/sek/jpy/",
#                 "description": "1 Swedish Krona = 13.411901 Japanese Yen",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "JPY",
#                 "targetName": "Japanese Yen",
#                 "exchangeRate": "13.411901",
#                 "inverseRate": "0.074561",
#                 "inverseDescription": "1 Japanese Yen = 0.074561 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.217468 BGN",
#                 "link": "http://www.floatrates.com/sek/bgn/",
#                 "description": "1 Swedish Krona = 0.217468 Bulgarian Lev",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "BGN",
#                 "targetName": "Bulgarian Lev",
#                 "exchangeRate": "0.217468",
#                 "inverseRate": "4.598377",
#                 "inverseDescription": "1 Bulgarian Lev = 4.598377 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.383922 LTL",
#                 "link": "http://www.floatrates.com/sek/ltl/",
#                 "description": "1 Swedish Krona = 0.383922 Lithuanian Litas",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "LTL",
#                 "targetName": "Lithuanian Litas",
#                 "exchangeRate": "0.383922",
#                 "inverseRate": "2.604699",
#                 "inverseDescription": "1 Lithuanian Litas = 2.604699 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.078890 LVL",
#                 "link": "http://www.floatrates.com/sek/lvl/",
#                 "description": "1 Swedish Krona = 0.078890 Latvian Lats",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "LVL",
#                 "targetName": "Latvian Lats",
#                 "exchangeRate": "0.078890",
#                 "inverseRate": "12.675835",
#                 "inverseDescription": "1 Latvian Lats = 12.675835 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.456996 RON",
#                 "link": "http://www.floatrates.com/sek/ron/",
#                 "description": "1 Swedish Krona = 0.456996 Romanian New Leu",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "RON",
#                 "targetName": "Romanian New Leu",
#                 "exchangeRate": "0.456996",
#                 "inverseRate": "2.188201",
#                 "inverseDescription": "1 Romanian New Leu = 2.188201 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.820759 HRK",
#                 "link": "http://www.floatrates.com/sek/hrk/",
#                 "description": "1 Swedish Krona = 0.820759 Croatian Kuna",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "HRK",
#                 "targetName": "Croatian Kuna",
#                 "exchangeRate": "0.820759",
#                 "inverseRate": "1.218384",
#                 "inverseDescription": "1 Croatian Kuna = 1.218384 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.254372 TRY",
#                 "link": "http://www.floatrates.com/sek/try/",
#                 "description": "1 Swedish Krona = 0.254372 Turkish Lira",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "TRY",
#                 "targetName": "Turkish Lira",
#                 "exchangeRate": "0.254372",
#                 "inverseRate": "3.931243",
#                 "inverseDescription": "1 Turkish Lira = 3.931243 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 0.262178 BRL",
#                 "link": "http://www.floatrates.com/sek/brl/",
#                 "description": "1 Swedish Krona = 0.262178 Brazilian Real",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "BRL",
#                 "targetName": "Brazilian Real",
#                 "exchangeRate": "0.262178",
#                 "inverseRate": "3.814201",
#                 "inverseDescription": "1 Brazilian Real = 3.814201 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 1.285628 HKD",
#                 "link": "http://www.floatrates.com/sek/hkd/",
#                 "description": "1 Swedish Krona = 1.285628 Hong Kong Dollar",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "HKD",
#                 "targetName": "Hong Kong Dollar",
#                 "exchangeRate": "1.285628",
#                 "inverseRate": "0.777830",
#                 "inverseDescription": "1 Hong Kong Dollar = 0.777830 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 1.914426 MXN",
#                 "link": "http://www.floatrates.com/sek/mxn/",
#                 "description": "1 Swedish Krona = 1.914426 Mexican Peso",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "MXN",
#                 "targetName": "Mexican Peso",
#                 "exchangeRate": "1.914426",
#                 "inverseRate": "0.522350",
#                 "inverseDescription": "1 Mexican Peso = 0.522350 Swedish Krona"
#             },
#             {
#                 "title": "1 SEK = 7.101125 PHP",
#                 "link": "http://www.floatrates.com/sek/php/",
#                 "description": "1 Swedish Krona = 7.101125 Philippine Peso",
#                 "pubDate": null,
#                 "baseCurrency": "SEK",
#                 "baseName": "Swedish Krona",
#                 "targetCurrency": "PHP",
#                 "targetName": "Philippine Peso",
#                 "exchangeRate": "7.101125",
#                 "inverseRate": "0.140823",
#                 "inverseDescription": "1 Philippine Peso = 0.140823 Swedish Krona"
#             }
#         ]
#     }
# }

# %% [markdown]
# --------------------------------------------
# # Quest 2 (50 XP): Decipher the scrolls – Exploratory Data Analysis
#
# Once the scrolls have been retrieved their knowledge remains unrefined there patterns hidden, trends veiled. Your task now is to become the Seer of Exchange, the one who can read the currencies’ fates through the lens of data.
# 8
# Perform Exploratory Data Analysis (EDA) on the dataset you collected in Quest 1.
# - Aggregate and visualize trends in exchange rate over time for at least 5 major currencies (e.g., USD, EUR, GBP, JPY, CNY).
#
# - Identify periods of volatility — perhaps during economic upheaval
#
# - Generate at least multiple visualizations using seaborn:
#
# - Log your quest progress in your quest book to show the Grand Master what you learned this is very important. some examples of observations are:
#     - Anomalies, seasonal patterns, or economic events
#     - Currencies with the most/least stability
#     - Any interesting correlations between currencies
#
#
# ## Notes from the Grand Master
# - All of your work in this section should be in your jupyter notebook.
#
# - It might be helpful to use  google to reveal how economic events affected currency. Use Google News or economic calendars to correlate real-world events to exchange rate spikes or dips.

# %% [markdown]
# --------------------------------------------

# %% [markdown]
# # Side Quest 1 (10 XP): Lay Down Seeds for Those Who Follow – Logging
#
# Even the greatest explorer must leave breadcrumbs for those who walk the path after them. Here you will construct an error log system, a journal that captures both triumphs and catastrophes.
#
# Implement a robust logging system throughout your codebase to monitor:
# - Successful currency downloads
# - Parsing attempts and failures
# - Skipped downloads (due to saved data or time out)
# - Connection errors
#
# ## Notes from the Grand Master
# - You do not need to do log hierarchy
# - Use log levels: INFO for progress, WARNING for skips, ERROR for failures

# %% [markdown]
# --------------------------------------------

# %% [markdown]
# # Side Quest 2 (10 XP): The quest of Reflection – Code Profiling
#
# The final challenge for any Adventure is introspection — learning the nature of one's own power. In this side quest, you will profile your code, to discover its bottlenecks, inefficiencies, and optimization opportunities.
#
# Use profiling tools to evaluate:
# - Which functions are taking the most time
# - How threads/processes are behaving
# - Whether I/O is a bottleneck
#
# *A random vendor appears* His invintory shows:
# - A Profiler function - cProfile or Profile
# - A time module - timeit for micro-benchmarks
# - A line profiler - line_profiler
